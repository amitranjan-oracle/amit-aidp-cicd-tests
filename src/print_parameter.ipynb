# %%
# Print the parameter (set at the task or the job level)
job_param_key = "job_param"
job_param_val = oidlUtils.parameters.getParameter(job_param_key, "-1")
print(f"Param: {job_param_key}, Value: {job_param_val}")

# %%
# Print the task parameter
task_param_key = "task_param"
task_param_val = oidlUtils.parameters.getParameter(task_param_key, "default_task_param")
print(f"Param: {task_param_key}, Value: {task_param_val}")

# %%
# print the parameter (set by other task) 

task_name = "set_parameter"  # name of the task that set the parameter 
task_param_key = "task_out_param" 
task_param_val = oidlUtils.parameters.getTaskValue(task_name, task_param_key, "-1") 
print(f"Param: {task_param_key}, Value: {task_param_val}")
