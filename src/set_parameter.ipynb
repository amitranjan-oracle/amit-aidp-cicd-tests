# %%
# Print the job parameter
job_param_key = "job_param"
job_param_val = oidlUtils.parameters.getParameter(job_param_key, "default_job_param")
print(f"Param: {job_param_key}, Value: {job_param_val}")

# %%
# Set parameter value in the task
from random import random 

task_param_key = "task_out_param" 
task_param_val = str(random()) 
oidlUtils.parameters.setTaskValue(task_param_key, task_param_val) 
print(f"Output value set as: {task_param_val}")
